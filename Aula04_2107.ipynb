# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandonakagawa/Python_TCS_100h/blob/main/Aula04_2107.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade 03

# %%
hora = int(input("Digite a hora do dia: "))
if hora < 0:
  print("hora inválida. Deve ser um valor maior ou igual a 0")
elif hora < 6:
  print("Boa madrugada")
elif hora < 12:
  print("Bom dia")
elif hora < 18:
  print("Boa tarde")
elif hora < 24:
  print("Boa noite")
else:
  print("hora inválida, deve ser menor que 24")
# Out:
# Digite a hora do dia: 25
# hora inválida, deve ser menor que 24

# %%
hora = int(input("Digite a hora do dia: "))
if hora < 0:
  print("hora inválida. Deve ser um valor maior ou igual a 0")
elif hora >= 0 and hora < 6:
  print("Boa madrugada")
elif hora >= 6 and hora < 12:
  print("Bom dia")
elif hora >= 12 and hora < 18:
  print("Boa tarde")
elif hora >= 18 and hora < 24:
  print("Boa noite")
else:
  print("hora inválida, deve ser menor que 24")
# Out:
# Digite a hora do dia: 7
# Bom dia

# %% [markdown]
# A medida de eficiência de um carro é medida em km/l (quantos km o
# carro anda com 1 litro de combustível). Faça um algoritmo que
# calcule a eficiência de um carro tendo como entrada a distância
# percorrida e a quantidade de combustível gasta em litros.
#
# Exemplo:
# distância percorrida = 300km
# quantidade gasta = 20 litros
# eficiência: 15km/l

# %%
distancia = float(input("Digite a distância percorrida: "))
qtd_combustivel = float(input("Digite a quantidade de combustível gasta em litros: "))
eficiencia = distancia/qtd_combustivel
print("A eficiência é de {:.1f} km/l.".format(eficiencia))
# Out:
# Digite a distância percorrida: 340.56
# Digite a quantidade de combustível gasta em litros: 18.7
# A eficiência é de 18.2 km/l.

# %% [markdown]
# Atualmente existem os carros flex, ou seja, podem ser abastecidos
# com etanol ou gasolina. Geralmente um carro flex abastecido a
# etanol tem uma eficiência menor do mesmo abastecido com gasolina.
#
# Faça um algoritmo que tendo como entrada: eficiência do carro
# abastecido à gasolina (em km/l), eficiência do carro abastecido
# com etanol (em km/l), preço da gasolina por litro e preço do
# etanol por litro e mostre o valor do km rodado com cada um dos
# combustíveis.
#
# Exemplo:
# eficiência com gasolina: 15km/l
# preço da gasolina: R\$ 4,50 por litro
# valor do km rodado com gasolina: R\$ 0,30
#
# eficiência com etanol: 10km/l
# preço do etanol: R\$ 3,50 por litro
# valor do km rodado com etanol: R\$ 0,35

# %%
eficiencia_gasolina = float(input("Digite a eficiência com gasolina: "))
eficiencia_etanol = float(input("Digite a eficiência com etanol: "))
preco_gasolina = float(input("Digite o preço da gasolina por litro: "))
preco_etanol = float(input("Digite o preço do etanol por litro: "))
km_gasolina = preco_gasolina / eficiencia_gasolina
km_etanol = preco_etanol / eficiencia_etanol
print("O valor do km rodado com gasolina é de R${:.2f} e com etanol é de R${:.2f}".format(km_gasolina, km_etanol))
if km_gasolina < km_etanol: print("A gasolina custa mais barato.")
else: print("O etanol custa mais barato.")
# Out:
# Digite a eficiência com gasolina: 15
# Digite a eficiência com etanol: 10
# Digite o preço da gasolina por litro: 4.50
# Digite o preço do etanol por litro: 3.50
# O valor do km rodado com gasolina é de R$0.30 e com etanol é de R$0.35
# A gasolina custa mais barato.

# %% [markdown]
# Um trabalhador trabalha 40 horas por semana. Escreva um algoritmo
# que leia o número de horas trabalhadas em cada semana de um mês,
# o salário por hora e escreva o salário total do mês do
# funcionário (considere que o mês possua 4 semanas exatas).

# %%
semana = 1
horas1 = int(input(f"Digite o número de horas da semana {semana}: "))
semana += 1
horas2 = int(input(f"Digite o número de horas da semana {semana}: "))
semana += 1
horas3 = int(input(f"Digite o número de horas da semana {semana}: "))
semana += 1
horas4 = int(input(f"Digite o número de horas da semana {semana}: "))
semana += 1
salario_hora = float(input("Digite o salário por hora: "))
total_horas = horas1 + horas2 + horas3 + horas4
total_salario = total_horas * salario_hora
print("O salário total do mês é de R${:.2f}".format(total_salario))
# Out:
# Digite o número de horas da semana 1: 40
# Digite o número de horas da semana 2: 38
# Digite o número de horas da semana 3: 36
# Digite o número de horas da semana 4: 34
# Digite o salário por hora: 190.45
# O salário total do mês é de R$28186.60

# %% [markdown]
# tenha como entrada dois números e exiba a sua divisão. Lembre-se
# que não é possível dividir por 0!

# %%
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
if n2 != 0:
  divisao = n1/n2
  print(f"O resultado da divisão do primeiro pelo segundo número é de {divisao}.")
else:
  print("Não é possível dividir por 0.")
# Out:
# Digite o primeiro número: 3
# Digite o segundo número: 2
# O resultado da divisão do primeiro pelo segundo número é de 1.5.

# %% [markdown]
# Ler uma nota de 0 à 10 de um aluno.
#
# Caso o usuário digite um
# valor inválido, mostrar a mensagem: &quot;Nota inválida! Digite um
# valor de 0 à 10!&quot;

# %%
nota = float(input("Digite a nota do aluno: "))
if nota < 0 or nota > 10: print("Nota inválida! Digite um valor de 0 à 10!")
# Out:
# Digite a nota do aluno: -1
# Nota inválida! Digite um valor de 0 à 10!

# %% [markdown]
# # Aula 04

# %%
a = 0
while a < 5:
  print(a)
  a += 1
# Out:
# 6

# %%
a = 0
while True:
  print(a)
  a += 1
  if a > 5: break
#break quebra o laço...

# %%
a = 0
flag = True
while flag:
  print(a)
  a += 1
  if a > 5: flag = False

# %%
a = 0
if a == 0:
  pass
print("blabla")
#pass não faz nada
# Out:
# blabla

# %%
a = 0
while a < 5:
  print(a)
  continue
  a += 1
#continue termina a volta

# %%
x = 0
while x <= 4:
  print("Olá")
  x += 1
# Out:
# Olá
# Olá
# Olá
# Olá
# Olá

# %%
#from google.colab.patches import cv2_imshow as cv2
import cv2

hora = int(input("Digite a hora do dia: "))
if hora >= 0 and hora < 6:
  print("Boa madrugada")
  caminho = "/content/drive/MyDrive/_2022/Python_32h/aula02/lua.jpg"
elif hora >= 6 and hora < 12:
  print("Bom dia")
  caminho = "/content/drive/MyDrive/_2022/Python_32h/aula02/bomdia.png"
elif hora >= 12 and hora < 18:
  print("Boa tarde")
  caminho = "/content/drive/MyDrive/_2022/Python_32h/aula02/boatarde.jpg"
elif hora >= 18 and hora < 24:
  print("Boa noite")
  caminho = "/content/drive/MyDrive/_2022/Python_32h/aula02/boanoite.png"
else:
  print("hora inválida.")
  caminho = "/content/drive/MyDrive/_2022/Python_32h/aula02/noidea.jpg"

img = cv2.imread(caminho)
cv2_imshow(img)
# Out:
# Digite a hora do dia: 2
# Boa madrugada
# <PIL.Image.Image image mode=RGB size=910x683 at 0x7F8AEFA070D0>

# %%
import cv2
# !wget --no-check-certificate \
    https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Tata_Consultancy_Services_Logo.svg/250px-Tata_Consultancy_Services_Logo.svg.png \
    -O tcs.jpg

img = cv2.imread("tcs.jpg")
cv2_imshow(img)
# Out:
# --2022-07-21 13:14:14--  https://upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Tata_Consultancy_Services_Logo.svg/250px-Tata_Consultancy_Services_Logo.svg.png
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.153.240, 2620:0:860:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.153.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9094 (8.9K) [image/png]
# Saving to: ‘tcs.jpg’
#
# tcs.jpg             100%[===================>]   8.88K  --.-KB/s    in 0s
#
# 2022-07-21 13:14:14 (76.8 MB/s) - ‘tcs.jpg’ saved [9094/9094]
# <PIL.Image.Image image mode=RGB size=250x100 at 0x7F8AED6A60D0>

# %%
#não aceitar números negativos
a = -1
while a < 0:
  a = int(input("Digite um número:"))
  if a < 0:
    print("Digite um número válido. ")
  else:
    print("Fim. ")
# Out:
# Digite um número-1
# Digite um número válido
# Digite um número2
# fim
